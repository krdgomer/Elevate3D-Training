# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ProjeDosyalari/Elevate3D/
# Out:
# /content/drive/MyDrive/ProjeDosyalari/Elevate3D

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 47 (delta 28), reused 43 (delta 24), pack-reused 0 (from 0)
# Unpacking objects: 100% (47/47), 7.61 KiB | 2.00 KiB/s, done.
# From https://github.com/krdgomer/Elevate3D
#  * branch            main       -> FETCH_HEAD
#    648730b..c065741  main       -> origin/main
# Updating 648730b..c065741
# Fast-forward
#  notebooks/train_rgb2dsm.ipynb         | 146 +++++-------------------------------------------------
#  src/BATC/training/dataset.py          |   6 +--
#  src/BATC/training/train.py            |  97 ++++++++++++++++++++++++++++++------
#  src/configs/maskrcnn_config.py        |   4 ++
#  src/configs/rgb2dsm_config.py         |   8 +--
#  src/rgb2dsm/test/calculate_errors.py  |   4 +-
#  src/rgb2dsm/training/discriminator.py |   3 +-
#  src/rgb2dsm/training/loss_function.py |  56 +++++++++++++++------
#  src/rgb2dsm/training/train.py         |   2 +-
#  9 files changed, 151 insertions(+), 175 deletions(-)
#  create mode 100644 src/configs/maskrcnn_config.py

# %%
import os
print(os.getcwd())
# Out:
# /content/drive/MyDrive/ProjeDosyalari/Elevate3D

# %%
import sys
sys.path.append('/content/drive/MyDrive/ProjeDosyalari/Elevate3D/src')
sys.path.append('/content/drive/MyDrive/ProjeDosyalari/Elevate3D/src/training')

# %%
# %cd /content/drive/MyDrive/ProjeDosyalari/Elevate3D
# !python -m src.rgb2dsm.training.train --train_dir "/content/drive/MyDrive/ProjeDosyalari/rgb2dsm/data/train" --val_dir "/content/drive/MyDrive/ProjeDosyalari/rgb2dsm/data/validation"
# Out:
# /content/drive/MyDrive/ProjeDosyalari/Elevate3D
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:06<00:00, 89.2MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Epoch 1/200
# 100% 196/196 [05:01<00:00,  1.54s/it, D_fake=0.252, D_real=0.745]
# Returned losses - Disc: 0.5557, Gen: 57.5910
# => Saving checkpoint
# => Saving checkpoint
# Epoch 2/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.261, D_real=0.709]
# Returned losses - Disc: 0.5444, Gen: 45.5111
# Epoch 3/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.279, D_real=0.718]
# Returned losses - Disc: 0.5117, Gen: 42.2397
# Epoch 4/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.277, D_real=0.691]
# Returned losses - Disc: 0.5063, Gen: 40.2549
# Epoch 5/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.442, D_real=0.483]
# Returned losses - Disc: 0.4621, Gen: 38.2975
# Epoch 6/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.173, D_real=0.825]
# Returned losses - Disc: 0.4829, Gen: 36.7222
# => Saving checkpoint
# => Saving checkpoint
# Epoch 7/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.203, D_real=0.798]
# Returned losses - Disc: 0.5160, Gen: 35.2967
# Epoch 8/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.277, D_real=0.666]
# Returned losses - Disc: 0.5018, Gen: 34.4774
# Epoch 9/200
# 100% 196/196 [03:31<00:00,  1.08s/it, D_fake=0.328, D_real=0.552]
# Returned losses - Disc: 0.5125, Gen: 34.5731
# Epoch 10/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.241, D_real=0.712]
# Returned losses - Disc: 0.5064, Gen: 33.9240
# Epoch 11/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.347, D_real=0.631]
# Returned losses - Disc: 0.5060, Gen: 32.7995
# => Saving checkpoint
# => Saving checkpoint
# Epoch 12/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.42, D_real=0.475]
# Returned losses - Disc: 0.5078, Gen: 34.2089
# Epoch 13/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.178, D_real=0.751]
# Returned losses - Disc: 0.5113, Gen: 32.3626
# Epoch 14/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.314, D_real=0.739]
# Returned losses - Disc: 0.5172, Gen: 31.1714
# Epoch 15/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.169, D_real=0.819]
# Returned losses - Disc: 0.5156, Gen: 30.9285
# Epoch 16/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.316, D_real=0.687]
# Returned losses - Disc: 0.5197, Gen: 30.5671
# => Saving checkpoint
# => Saving checkpoint
# Epoch 17/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.282, D_real=0.705]
# Returned losses - Disc: 0.5179, Gen: 29.6355
# Epoch 18/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.466, D_real=0.541]
# Returned losses - Disc: 0.5274, Gen: 29.3002
# Epoch 19/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.383, D_real=0.59]
# Returned losses - Disc: 0.5182, Gen: 29.7118
# Epoch 20/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.25, D_real=0.654]
# Returned losses - Disc: 0.5269, Gen: 29.5132
# Epoch 21/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.204, D_real=0.706]
# Returned losses - Disc: 0.5218, Gen: 28.1168
# => Saving checkpoint
# => Saving checkpoint
# Epoch 22/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.267, D_real=0.757]
# Returned losses - Disc: 0.5265, Gen: 28.0943
# Epoch 23/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.193, D_real=0.765]
# Returned losses - Disc: 0.5307, Gen: 27.6249
# Epoch 24/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.436, D_real=0.547]
# Returned losses - Disc: 0.5359, Gen: 27.0486
# Epoch 25/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.239, D_real=0.681]
# Returned losses - Disc: 0.5398, Gen: 26.7674
# Epoch 26/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.344, D_real=0.595]
# Returned losses - Disc: 0.5332, Gen: 26.2575
# => Saving checkpoint
# => Saving checkpoint
# Epoch 27/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.436, D_real=0.617]
# Returned losses - Disc: 0.5408, Gen: 25.7221
# Epoch 28/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.28, D_real=0.709]
# Returned losses - Disc: 0.5419, Gen: 25.5921
# Epoch 29/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.293, D_real=0.622]
# Returned losses - Disc: 0.5459, Gen: 24.5552
# Epoch 30/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.318, D_real=0.641]
# Returned losses - Disc: 0.5372, Gen: 24.5077
# Epoch 31/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.204, D_real=0.791]
# Returned losses - Disc: 0.5472, Gen: 23.9889
# => Saving checkpoint
# => Saving checkpoint
# Epoch 32/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.168, D_real=0.786]
# Returned losses - Disc: 0.5463, Gen: 23.6575
# Epoch 33/200
# 100% 196/196 [03:36<00:00,  1.10s/it, D_fake=0.343, D_real=0.64]
# Returned losses - Disc: 0.5478, Gen: 23.5110
# Epoch 34/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.275, D_real=0.768]
# Returned losses - Disc: 0.5490, Gen: 23.0490
# Epoch 35/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.397, D_real=0.606]
# Returned losses - Disc: 0.5431, Gen: 22.6031
# Epoch 36/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.298, D_real=0.673]
# Returned losses - Disc: 0.5543, Gen: 21.8649
# => Saving checkpoint
# => Saving checkpoint
# Epoch 37/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.511, D_real=0.411]
# Returned losses - Disc: 0.5636, Gen: 21.3750
# Epoch 38/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.411, D_real=0.501]
# Returned losses - Disc: 0.5467, Gen: 21.2666
# Epoch 39/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.64, D_real=0.266]
# Returned losses - Disc: 0.5493, Gen: 21.0328
# Epoch 40/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.405, D_real=0.552]
# Returned losses - Disc: 0.5506, Gen: 20.4345
# Epoch 41/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.501, D_real=0.413]
# Returned losses - Disc: 0.5532, Gen: 20.2287
# => Saving checkpoint
# => Saving checkpoint
# Epoch 42/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.387, D_real=0.596]
# Returned losses - Disc: 0.5495, Gen: 20.5096
# Epoch 43/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.288, D_real=0.695]
# Returned losses - Disc: 0.5589, Gen: 19.7975
# Epoch 44/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.371, D_real=0.643]
# Returned losses - Disc: 0.5524, Gen: 19.6222
# Epoch 45/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.505, D_real=0.536]
# Returned losses - Disc: 0.5603, Gen: 19.3104
# Epoch 46/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.278, D_real=0.712]
# Returned losses - Disc: 0.5540, Gen: 19.0155
# => Saving checkpoint
# => Saving checkpoint
# Epoch 47/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.241, D_real=0.71]
# Returned losses - Disc: 0.5625, Gen: 18.9452
# Epoch 48/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.417, D_real=0.532]
# Returned losses - Disc: 0.5535, Gen: 18.5294
# Epoch 49/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.336, D_real=0.662]
# Returned losses - Disc: 0.5493, Gen: 18.4982
# Epoch 50/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.349, D_real=0.524]
# Returned losses - Disc: 0.5602, Gen: 18.1820
# Epoch 51/200
# 100% 196/196 [03:32<00:00,  1.08s/it, D_fake=0.373, D_real=0.604]
# Returned losses - Disc: 0.5596, Gen: 17.8452
# => Saving checkpoint
# => Saving checkpoint
# Epoch 52/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.181, D_real=0.869]
# Returned losses - Disc: 0.5619, Gen: 18.1932
# Epoch 53/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.389, D_real=0.585]
# Returned losses - Disc: 0.5594, Gen: 17.5667
# Epoch 54/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.385, D_real=0.653]
# Returned losses - Disc: 0.5606, Gen: 17.7698
# Epoch 55/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.457, D_real=0.444]
# Returned losses - Disc: 0.5607, Gen: 17.6244
# Epoch 56/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.389, D_real=0.499]
# Returned losses - Disc: 0.5661, Gen: 17.0845
# => Saving checkpoint
# => Saving checkpoint
# Epoch 57/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.349, D_real=0.66]
# Returned losses - Disc: 0.5657, Gen: 17.0356
# Epoch 58/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.394, D_real=0.63]
# Returned losses - Disc: 0.5585, Gen: 16.6918
# Epoch 59/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.496, D_real=0.473]
# Returned losses - Disc: 0.6107, Gen: 17.2233
# Epoch 60/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.348, D_real=0.624]
# Returned losses - Disc: 0.5601, Gen: 16.3809
# Epoch 61/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.472, D_real=0.42]
# Returned losses - Disc: 0.5599, Gen: 16.4273
# => Saving checkpoint
# => Saving checkpoint
# Epoch 62/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.385, D_real=0.656]
# Returned losses - Disc: 0.5817, Gen: 16.2000
# Epoch 63/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.202, D_real=0.735]
# Returned losses - Disc: 0.5611, Gen: 15.9065
# Epoch 64/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.347, D_real=0.593]
# Returned losses - Disc: 0.5555, Gen: 15.8708
# Epoch 65/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.249, D_real=0.732]
# Returned losses - Disc: 0.5682, Gen: 15.7182
# Epoch 66/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.506, D_real=0.405]
# Returned losses - Disc: 0.5711, Gen: 15.4844
# => Saving checkpoint
# => Saving checkpoint
# Epoch 67/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.154, D_real=0.768]
# Returned losses - Disc: 0.5594, Gen: 15.5758
# Epoch 68/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.344, D_real=0.633]
# Returned losses - Disc: 0.5718, Gen: 15.3403
# Epoch 69/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.44, D_real=0.474]
# Returned losses - Disc: 0.5988, Gen: 15.2910
# Epoch 70/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.354, D_real=0.656]
# Returned losses - Disc: 0.5554, Gen: 14.9921
# Epoch 71/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.292, D_real=0.71]
# Returned losses - Disc: 0.5640, Gen: 15.1561
# => Saving checkpoint
# => Saving checkpoint
# Epoch 72/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.494, D_real=0.49]
# Returned losses - Disc: 0.5429, Gen: 15.2383
# Epoch 73/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.194, D_real=0.715]
# Returned losses - Disc: 0.5595, Gen: 14.9226
# Epoch 74/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.267, D_real=0.672]
# Returned losses - Disc: 0.5498, Gen: 14.7707
# Epoch 75/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.506, D_real=0.47]
# Returned losses - Disc: 0.6386, Gen: 14.2135
# Epoch 76/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.298, D_real=0.647]
# Returned losses - Disc: 0.5460, Gen: 14.2953
# => Saving checkpoint
# => Saving checkpoint
# Epoch 77/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.375, D_real=0.649]
# Returned losses - Disc: 0.5907, Gen: 14.1617
# Epoch 78/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.318, D_real=0.633]
# Returned losses - Disc: 0.5345, Gen: 14.1420
# Epoch 79/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.512, D_real=0.463]
# Returned losses - Disc: 0.5857, Gen: 14.3319
# Epoch 80/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.249, D_real=0.759]
# Returned losses - Disc: 0.5792, Gen: 13.6103
# Epoch 81/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.26, D_real=0.722]
# Returned losses - Disc: 0.5324, Gen: 14.0615
# => Saving checkpoint
# => Saving checkpoint
# Epoch 82/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.638, D_real=0.401]
# Returned losses - Disc: 0.5849, Gen: 13.7688
# Epoch 83/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.307, D_real=0.618]
# Returned losses - Disc: 0.5137, Gen: 13.9244
# Epoch 84/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.443, D_real=0.41]
# Returned losses - Disc: 0.5337, Gen: 13.8768
# Epoch 85/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.292, D_real=0.612]
# Returned losses - Disc: 0.5048, Gen: 13.8798
# Epoch 86/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.505, D_real=0.441]
# Returned losses - Disc: 0.5960, Gen: 13.4403
# => Saving checkpoint
# => Saving checkpoint
# Epoch 87/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.189, D_real=0.719]
# Returned losses - Disc: 0.5139, Gen: 13.5941
# Epoch 88/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.177, D_real=0.764]
# Returned losses - Disc: 0.4963, Gen: 13.5994
# Epoch 89/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.483, D_real=0.522]
# Returned losses - Disc: 0.5846, Gen: 13.6380
# Epoch 90/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.438, D_real=0.56]
# Returned losses - Disc: 0.6785, Gen: 12.2156
# Epoch 91/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.292, D_real=0.652]
# Returned losses - Disc: 0.4956, Gen: 13.2009
# => Saving checkpoint
# => Saving checkpoint
# Epoch 92/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.267, D_real=0.712]
# Returned losses - Disc: 0.4763, Gen: 13.9514
# Epoch 93/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.257, D_real=0.657]
# Returned losses - Disc: 0.4862, Gen: 13.4883
# Epoch 94/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.138, D_real=0.839]
# Returned losses - Disc: 0.4812, Gen: 13.3861
# Epoch 95/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.114, D_real=0.848]
# Returned losses - Disc: 0.4582, Gen: 14.2448
# Epoch 96/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.272, D_real=0.692]
# Returned losses - Disc: 0.5002, Gen: 13.2523
# => Saving checkpoint
# => Saving checkpoint
# Epoch 97/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.185, D_real=0.737]
# Returned losses - Disc: 0.4613, Gen: 13.4295
# Epoch 98/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.245, D_real=0.666]
# Returned losses - Disc: 0.6105, Gen: 12.5527
# Epoch 99/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.268, D_real=0.67]
# Returned losses - Disc: 0.4507, Gen: 13.1119
# Epoch 100/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.262, D_real=0.574]
# Returned losses - Disc: 0.4773, Gen: 13.2684
# Epoch 101/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.228, D_real=0.651]
# Returned losses - Disc: 0.6379, Gen: 12.4693
# => Saving checkpoint
# => Saving checkpoint
# Epoch 102/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.466, D_real=0.5]
# Returned losses - Disc: 0.6386, Gen: 12.1726
# Epoch 103/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.241, D_real=0.634]
# Returned losses - Disc: 0.5244, Gen: 12.2767
# Epoch 104/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.37, D_real=0.596]
# Returned losses - Disc: 0.4955, Gen: 12.9902
# Epoch 105/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.246, D_real=0.755]
# Returned losses - Disc: 0.5357, Gen: 12.4541
# Epoch 106/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.281, D_real=0.619]
# Returned losses - Disc: 0.4374, Gen: 15.1256
# => Saving checkpoint
# => Saving checkpoint
# Epoch 107/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.154, D_real=0.825]
# Returned losses - Disc: 0.4726, Gen: 13.7469
# Epoch 108/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.0848, D_real=0.854]
# Returned losses - Disc: 0.5368, Gen: 12.4926
# Epoch 109/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.152, D_real=0.825]
# Returned losses - Disc: 0.4855, Gen: 12.5361
# Epoch 110/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.281, D_real=0.646]
# Returned losses - Disc: 0.5026, Gen: 12.5358
# Epoch 111/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.207, D_real=0.77]
# Returned losses - Disc: 0.4811, Gen: 12.4563
# => Saving checkpoint
# => Saving checkpoint
# Epoch 112/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.49, D_real=0.49]
# Returned losses - Disc: 0.5670, Gen: 12.2919
# Epoch 113/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.239, D_real=0.79]
# Returned losses - Disc: 0.6015, Gen: 11.3988
# Epoch 114/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.492, D_real=0.375]
# Returned losses - Disc: 0.4709, Gen: 12.2952
# Epoch 115/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.166, D_real=0.69]
# Returned losses - Disc: 0.4745, Gen: 12.2678
# Epoch 116/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.249, D_real=0.696]
# Returned losses - Disc: 0.4921, Gen: 12.2805
# => Saving checkpoint
# => Saving checkpoint
# Epoch 117/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.134, D_real=0.792]
# Returned losses - Disc: 0.4775, Gen: 12.2119
# Epoch 118/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.195, D_real=0.764]
# Returned losses - Disc: 0.5388, Gen: 12.0552
# Epoch 119/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.167, D_real=0.78]
# Returned losses - Disc: 0.4853, Gen: 12.1783
# Epoch 120/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.401, D_real=0.457]
# Returned losses - Disc: 0.4722, Gen: 12.3009
# Epoch 121/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.0472, D_real=0.91]
# Returned losses - Disc: 0.4750, Gen: 12.2665
# => Saving checkpoint
# => Saving checkpoint
# Epoch 122/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.289, D_real=0.663]
# Returned losses - Disc: 0.4728, Gen: 12.0660
# Epoch 123/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.494, D_real=0.508]
# Returned losses - Disc: 0.7402, Gen: 11.1276
# Epoch 124/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.369, D_real=0.62]
# Returned losses - Disc: 0.6623, Gen: 11.0564
# Epoch 125/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.272, D_real=0.629]
# Returned losses - Disc: 0.5421, Gen: 11.3862
# Epoch 126/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.159, D_real=0.819]
# Returned losses - Disc: 0.4572, Gen: 11.9506
# => Saving checkpoint
# => Saving checkpoint
# Epoch 127/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.212, D_real=0.73]
# Returned losses - Disc: 0.5743, Gen: 11.3361
# Epoch 128/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.203, D_real=0.684]
# Returned losses - Disc: 0.4656, Gen: 11.7870
# Epoch 129/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.152, D_real=0.805]
# Returned losses - Disc: 0.5059, Gen: 11.7316
# Epoch 130/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.329, D_real=0.53]
# Returned losses - Disc: 0.4977, Gen: 11.7189
# Epoch 131/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.328, D_real=0.521]
# Returned losses - Disc: 0.5166, Gen: 11.3726
# => Saving checkpoint
# => Saving checkpoint
# Epoch 132/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.438, D_real=0.555]
# Returned losses - Disc: 0.6648, Gen: 10.8345
# Epoch 133/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.223, D_real=0.673]
# Returned losses - Disc: 0.5660, Gen: 10.7256
# Epoch 134/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.245, D_real=0.687]
# Returned losses - Disc: 0.4643, Gen: 11.4948
# Epoch 135/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.688, D_real=0.366]
# Returned losses - Disc: 0.5858, Gen: 11.0023
# Epoch 136/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.211, D_real=0.755]
# Returned losses - Disc: 0.4637, Gen: 11.5259
# => Saving checkpoint
# => Saving checkpoint
# Epoch 137/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.233, D_real=0.663]
# Returned losses - Disc: 0.4972, Gen: 11.4842
# Epoch 138/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.246, D_real=0.654]
# Returned losses - Disc: 0.5054, Gen: 11.2035
# Epoch 139/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.248, D_real=0.687]
# Returned losses - Disc: 0.4874, Gen: 11.3093
# Epoch 140/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.144, D_real=0.803]
# Returned losses - Disc: 0.4970, Gen: 11.2988
# Epoch 141/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.363, D_real=0.63]
# Returned losses - Disc: 0.5094, Gen: 11.3720
# => Saving checkpoint
# => Saving checkpoint
# Epoch 142/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.164, D_real=0.743]
# Returned losses - Disc: 0.4500, Gen: 11.6394
# Epoch 143/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.26, D_real=0.718]
# Returned losses - Disc: 0.4919, Gen: 11.4856
# Epoch 144/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.28, D_real=0.656]
# Returned losses - Disc: 0.5199, Gen: 11.2054
# Epoch 145/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.134, D_real=0.799]
# Returned losses - Disc: 0.4824, Gen: 11.1621
# Epoch 146/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.482, D_real=0.651]
# Returned losses - Disc: 0.4863, Gen: 11.1703
# => Saving checkpoint
# => Saving checkpoint
# Epoch 147/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.255, D_real=0.771]
# Returned losses - Disc: 0.7033, Gen: 10.1924
# Epoch 148/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.331, D_real=0.575]
# Returned losses - Disc: 0.5748, Gen: 10.3699
# Epoch 149/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.14, D_real=0.858]
# Returned losses - Disc: 0.4818, Gen: 10.9983
# Epoch 150/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.244, D_real=0.677]
# Returned losses - Disc: 0.5023, Gen: 10.7661
# Epoch 151/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.274, D_real=0.655]
# Returned losses - Disc: 0.4765, Gen: 11.1096
# => Saving checkpoint
# => Saving checkpoint
# Epoch 152/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.378, D_real=0.598]
# Returned losses - Disc: 0.5947, Gen: 10.5168
# Epoch 153/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.0979, D_real=0.895]
# Returned losses - Disc: 0.5229, Gen: 10.5941
# Epoch 154/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.312, D_real=0.448]
# Returned losses - Disc: 0.5190, Gen: 10.6931
# Epoch 155/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.505, D_real=0.554]
# Returned losses - Disc: 0.6107, Gen: 10.4665
# Epoch 156/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.219, D_real=0.727]
# Returned losses - Disc: 0.6586, Gen: 9.4717
# => Saving checkpoint
# => Saving checkpoint
# Epoch 157/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.261, D_real=0.715]
# Returned losses - Disc: 0.5708, Gen: 10.2636
# Epoch 158/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.271, D_real=0.549]
# Returned losses - Disc: 0.4983, Gen: 10.6096
# Epoch 159/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.0582, D_real=0.844]
# Returned losses - Disc: 0.4851, Gen: 10.6296
# Epoch 160/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.501, D_real=0.557]
# Returned losses - Disc: 0.4938, Gen: 10.5625
# Epoch 161/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.209, D_real=0.772]
# Returned losses - Disc: 0.5143, Gen: 10.4694
# => Saving checkpoint
# => Saving checkpoint
# Epoch 162/200
# 100% 196/196 [03:35<00:00,  1.10s/it, D_fake=0.344, D_real=0.728]
# Returned losses - Disc: 0.4607, Gen: 10.6972
# Epoch 163/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.182, D_real=0.714]
# Returned losses - Disc: 0.4944, Gen: 10.4517
# Epoch 164/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.244, D_real=0.729]
# Returned losses - Disc: 0.4839, Gen: 10.5511
# Epoch 165/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.423, D_real=0.54]
# Returned losses - Disc: 0.4535, Gen: 13.7833
# Epoch 166/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.204, D_real=0.768]
# Returned losses - Disc: 0.5289, Gen: 10.8655
# => Saving checkpoint
# => Saving checkpoint
# Epoch 167/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.264, D_real=0.687]
# Returned losses - Disc: 0.4928, Gen: 10.5031
# Epoch 168/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.0615, D_real=0.887]
# Returned losses - Disc: 0.4540, Gen: 10.7318
# Epoch 169/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.151, D_real=0.786]
# Returned losses - Disc: 0.4664, Gen: 10.5102
# Epoch 170/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.413, D_real=0.542]
# Returned losses - Disc: 0.6204, Gen: 9.6665
# Epoch 171/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.245, D_real=0.449]
# Returned losses - Disc: 0.5203, Gen: 10.0991
# => Saving checkpoint
# => Saving checkpoint
# Epoch 172/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.207, D_real=0.675]
# Returned losses - Disc: 0.4771, Gen: 10.2703
# Epoch 173/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.231, D_real=0.757]
# Returned losses - Disc: 0.4830, Gen: 10.2561
# Epoch 174/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.252, D_real=0.651]
# Returned losses - Disc: 0.4819, Gen: 10.4359
# Epoch 175/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.383, D_real=0.516]
# Returned losses - Disc: 0.5212, Gen: 10.0736
# Epoch 176/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.277, D_real=0.7]
# Returned losses - Disc: 0.4989, Gen: 10.0591
# => Saving checkpoint
# => Saving checkpoint
# Epoch 177/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.132, D_real=0.9]
# Returned losses - Disc: 0.5214, Gen: 10.0498
# Epoch 178/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.449, D_real=0.537]
# Returned losses - Disc: 0.6316, Gen: 9.6692
# Epoch 179/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.242, D_real=0.591]
# Returned losses - Disc: 0.4867, Gen: 9.9474
# Epoch 180/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.149, D_real=0.832]
# Returned losses - Disc: 0.5051, Gen: 10.0473
# Epoch 181/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.313, D_real=0.659]
# Returned losses - Disc: 0.4726, Gen: 10.1434
# => Saving checkpoint
# => Saving checkpoint
# Epoch 182/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.469, D_real=0.533]
# Returned losses - Disc: 0.6515, Gen: 9.7551
# Epoch 183/200
# 100% 196/196 [03:32<00:00,  1.09s/it, D_fake=0.345, D_real=0.623]
# Returned losses - Disc: 0.6683, Gen: 8.9255
# Epoch 184/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.216, D_real=0.756]
# Returned losses - Disc: 0.5261, Gen: 9.6225
# Epoch 185/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.225, D_real=0.74]
# Returned losses - Disc: 0.3797, Gen: 15.7699
# Epoch 186/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.384, D_real=0.52]
# Returned losses - Disc: 0.4550, Gen: 11.2009
# => Saving checkpoint
# => Saving checkpoint
# Epoch 187/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.343, D_real=0.636]
# Returned losses - Disc: 0.7011, Gen: 9.2364
# Epoch 188/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.238, D_real=0.706]
# Returned losses - Disc: 0.4871, Gen: 9.8148
# Epoch 189/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.264, D_real=0.791]
# Returned losses - Disc: 0.4860, Gen: 9.8430
# Epoch 190/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.172, D_real=0.724]
# Returned losses - Disc: 0.4498, Gen: 10.1118
# Epoch 191/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.396, D_real=0.599]
# Returned losses - Disc: 0.4923, Gen: 9.9665
# => Saving checkpoint
# => Saving checkpoint
# Epoch 192/200
# 100% 196/196 [03:34<00:00,  1.10s/it, D_fake=0.182, D_real=0.688]
# Returned losses - Disc: 0.4708, Gen: 9.9142
# Epoch 193/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.261, D_real=0.703]
# Returned losses - Disc: 0.4741, Gen: 9.9284
# Epoch 194/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.474, D_real=0.487]
# Returned losses - Disc: 0.7523, Gen: 8.9580
# Epoch 195/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.466, D_real=0.534]
# Returned losses - Disc: 0.6852, Gen: 8.3917
# Epoch 196/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.297, D_real=0.683]
# Returned losses - Disc: 0.6313, Gen: 8.6251
# => Saving checkpoint
# => Saving checkpoint
# Epoch 197/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.149, D_real=0.814]
# Returned losses - Disc: 0.5459, Gen: 9.3572
# Epoch 198/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.364, D_real=0.607]
# Returned losses - Disc: 0.4908, Gen: 9.7555
# Epoch 199/200
# 100% 196/196 [03:34<00:00,  1.09s/it, D_fake=0.202, D_real=0.791]
# Returned losses - Disc: 0.4724, Gen: 9.9629
# Epoch 200/200
# 100% 196/196 [03:33<00:00,  1.09s/it, D_fake=0.055, D_real=0.821]
# Returned losses - Disc: 0.4624, Gen: 9.8150
# Figure(640x480)
